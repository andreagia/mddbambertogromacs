# %%
import parmed as pmd

# %%
amber = pmd.load_file('./ferrcar.prmtop', './ferrcar.inpcrd')

# %%
print(amber)
print("Numero di atomi:", len(amber.atoms))
print("Box (se presente):", amber.box)
# Out:
# ./files/fer_car/1-preparazione/tleap_wat/ferrcar.prmtop
# Numero di atomi: 355852
# Box (se presente): [160.2179329 160.2179329 160.2179329 109.471219  109.471219  109.471219 ]

# %%
amber.save('./gromacs/system.top', format='gromacs', overwrite=True)
amber.save('./gromacs/system.gro', overwrite=True)
